# %%
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table')
print(df)
# Out:
# [                                       Olympic Games
# 0                                        Main topics
# 1  Bids Boycotts Ceremonies Charter Host cities I...
# 2                                              Games
# 3  Summer Winter Youth African Asian European Pac...
# 4  .mw-parser-output .navbar{display:inline;font-...,                                              Team Summer Games  \
#                                   Team (IOC code)            №
# 0                               Afghanistan (AFG)           14
# 1                                   Algeria (ALG)           13
# 2                                 Argentina (ARG)           24
# 3                                   Armenia (ARM)            6
# 4                         Australasia (ANZ) [ANZ]            2
# ..                                            ...          ...
# 148                          Zimbabwe (ZIM) [ZIM]           13
# 149      Independent Olympic Athletes (IOA) [IOA]            3
# ...

# %%
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table')
df[1]
# Out:
#                                              Team Summer Games  \
#                                   Team (IOC code)            №
# 0                               Afghanistan (AFG)           14
# 1                                   Algeria (ALG)           13
# 2                                 Argentina (ARG)           24
# 3                                   Armenia (ARM)            6
# 4                         Australasia (ANZ) [ANZ]            2
# ..                                            ...          ...
# 148                          Zimbabwe (ZIM) [ZIM]           13
# 149      Independent Olympic Athletes (IOA) [IOA]            3
# 150  Independent Olympic Participants (IOP) [IOP]            1
# 151                        Mixed team (ZZX) [ZZX]            3
# 152                                        Totals           28
#
#                                                                      \
#     Unnamed: 2_level_1 Unnamed: 3_level_1 Unnamed: 4_level_1  Total
# ...

# %%
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table',
                 header = 0, index_col = 0)
df[1]
# Out:
#                                              Summer Games  Summer Games.1  \
# Team
# Team (IOC code)                                         №             NaN
# Afghanistan (AFG)                                      14             0.0
# Algeria (ALG)                                          13             5.0
# Argentina (ARG)                                        24            21.0
# Armenia (ARM)                                           6             2.0
# ...                                                   ...             ...
# Zimbabwe (ZIM) [ZIM]                                   13             3.0
# Independent Olympic Athletes (IOA) [IOA]                3             1.0
# Independent Olympic Participants (IOP) [IOP]            1             0.0
# Mixed team (ZZX) [ZZX]                                  3             8.0
# Totals                                                 28          5116.0
#
# ...

# %%
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table',
                 header = 0, index_col = 0)
summer = df[1].iloc[:,:5]  # df[1] 상에서 슬라이싱 할건데, 열은 전체, column은 5 미만까지 출력해라
summer.columns = ['경기수', '금', '은', '동', '계']
summer
# Out:
#                                              경기수       금       은       동  \
# Team
# Team (IOC code)                                №     NaN     NaN     NaN
# Afghanistan (AFG)                             14     0.0     0.0     2.0
# Algeria (ALG)                                 13     5.0     4.0     8.0
# Argentina (ARG)                               24    21.0    25.0    28.0
# Armenia (ARM)                                  6     2.0     6.0     6.0
# ...                                           ..     ...     ...     ...
# Zimbabwe (ZIM) [ZIM]                          13     3.0     4.0     1.0
# Independent Olympic Athletes (IOA) [IOA]       3     1.0     0.0     1.0
# Independent Olympic Participants (IOP) [IOP]   1     0.0     1.0     2.0
# Mixed team (ZZX) [ZZX]                         3     8.0     5.0     4.0
# Totals                                        28  5116.0  5080.0  5487.0
#
#                                                   계
# Team
# ...

# %%
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table',
                 header = 0, index_col = 0)
winter = df[1].iloc[:,5:10]  
winter
# Out:
#                                              Winter Games  Winter Games.1  \
# Team
# Team (IOC code)                                         №             NaN
# Afghanistan (AFG)                                       0             0.0
# Algeria (ALG)                                           3             0.0
# Argentina (ARG)                                        19             0.0
# Armenia (ARM)                                           7             0.0
# ...                                                   ...             ...
# Zimbabwe (ZIM) [ZIM]                                    1             0.0
# Independent Olympic Athletes (IOA) [IOA]                0             0.0
# Independent Olympic Participants (IOP) [IOP]            0             0.0
# Mixed team (ZZX) [ZZX]                                  0             0.0
# Totals                                                 23          1062.0
#
# ...

# %%
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table',
                 header = 0, index_col = 0)
summer = df[1].iloc[1:,:5] # 보니까 0열은 team, N, NaN 이런거 있어서 필요없길래 인덱싱으로 제외
summer.columns = ['경기수', '금', '은', '동', '계']
summer.sort_values('금',ascending = False) # '금' column을 기준으로 내림차순 정렬하고 싶어서 false로. 오름차순 하려면 true
# Out:
#                                         경기수       금       은       동      계
# Team
# Totals                                   28  5116.0  5080.0  5487.0  15683
# United States (USA) [P] [Q] [R] [Z] [F]  27  1022.0   795.0   706.0   2523
# Soviet Union (URS) [URS]                  9   395.0   319.0   296.0   1010
# Great Britain (GBR) [GBR] [Z]            28   263.0   295.0   293.0    851
# China (CHN) [CHN]                        10   224.0   167.0   155.0    546
# ...                                      ..     ...     ...     ...    ...
# Lebanon (LIB)                            17     0.0     2.0     2.0      4
# Eritrea (ERI)                             5     0.0     0.0     1.0      1
# Serbia and Montenegro (SCG) [SCG]         1     0.0     2.0     0.0      2
# Djibouti (DJI) [B]                        8     0.0     0.0     1.0      1
# Afghanistan (AFG)                        14     0.0     0.0     2.0      2
#
# [153 rows x 5 columns]

# %%
summer.to_excel('하계올림픽메달.xlsx')

# %%
import pandas as pd
index = pd.date_range('1/1/2000',periods=8) # datetime64 라는 data type으로 8개 index로 지정한 것.
print(index)
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np
import pandas as pd
index = pd.date_range('1/1/2000',periods=8) # datetime64 라는 data type으로 8개 index로 지정한 것.
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
print(df)
print(df['C'])
# Out:
#                    A         B         C
# 2000-01-01  0.838345  0.900021  0.270616
# 2000-01-02  0.342217  0.726261  0.813064
# 2000-01-03  0.699915  0.836225  0.150917
# 2000-01-04  0.249506  0.220720  0.029116
# 2000-01-05  0.656773  0.125478  0.697724
# 2000-01-06  0.203991  0.775779  0.501708
# 2000-01-07  0.337463  0.254569  0.173740
# 2000-01-08  0.299830  0.726238  0.621516
# 2000-01-01    0.270616
# 2000-01-02    0.813064
# 2000-01-03    0.150917
# 2000-01-04    0.029116
# 2000-01-05    0.697724
# 2000-01-06    0.501708
# 2000-01-07    0.173740
# 2000-01-08    0.621516
# Freq: D, Name: C, dtype: float64

# %%
import numpy as np
import pandas as pd
index = pd.date_range('1/1/2000',periods=8) 
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
df2=df[df['B']>0.4]
df2
# Out:
#                    A         B         C
# 2000-01-02  0.694894  0.749302  0.848571
# 2000-01-04  0.916912  0.488003  0.689830
# 2000-01-05  0.300593  0.624066  0.374934
# 2000-01-07  0.558522  0.964622  0.461514
# 2000-01-08  0.033858  0.483149  0.148891

# %%
df2.T
# Out:
#    2000-01-02  2000-01-04  2000-01-05  2000-01-07  2000-01-08
# A    0.694894    0.916912    0.300593    0.558522    0.033858
# B    0.749302    0.488003    0.624066    0.964622    0.483149
# C    0.848571    0.689830    0.374934    0.461514    0.148891

# %%
import numpy as np
import pandas as pd
index = pd.date_range('1/1/2000',periods=8) 
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
df['D'] = df['A']/df['B']
df
# Out:
#                    A         B         C          D
# 2000-01-01  0.290539  0.499476  0.067064   0.581689
# 2000-01-02  0.908978  0.062334  0.199710  14.582296
# 2000-01-03  0.353013  0.746019  0.737591   0.473195
# 2000-01-04  0.993571  0.346321  0.093400   2.868933
# 2000-01-05  0.985726  0.882354  0.427913   1.117155
# 2000-01-06  0.316319  0.568024  0.916712   0.556876
# 2000-01-07  0.267339  0.824817  0.824185   0.324120
# 2000-01-08  0.141925  0.849242  0.466054   0.167120

# %%
import numpy as np
import pandas as pd
index = pd.date_range('1/1/2000',periods=8) 
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
df['D']=df['A']/df['B']
df['E'] = np.sum(df, axis=1)  # 열 방향 축을 기준으로 행 우선 계산값을 E열에 저장. 
df.head()  # 많은 데이터 중 처음 5개 데이터만 불러오는 함수
# Out:
#                    A         B         C          D          E
# 2000-01-01  0.825878  0.444231  0.229439   1.859120   3.358667
# 2000-01-02  0.274479  0.990216  0.572939   0.277191   2.114826
# 2000-01-03  0.685939  0.045975  0.909848  14.919866  16.561627
# 2000-01-04  0.923436  0.695327  0.708074   1.328060   3.654897
# 2000-01-05  0.138281  0.378468  0.817525   0.365370   1.699644

# %%
import numpy as np
import pandas as pd
index = pd.date_range('1/1/2000',periods=8) 
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
df['D']=df['A']/df['B']
df['E'] = np.sum(df, axis=1)
df = df.sub(df['A'], axis=0) # A열의 데이터를 기준으로 열 우선 계산. 전체 데이터를 A열 값으로 빼기(sub)
df.head()
# Out:
#               A         B         C          D          E
# 2000-01-01  0.0  0.065251 -0.405382   0.302611   1.760031
# 2000-01-02  0.0 -0.801915  0.049385  91.355819  93.035422
# 2000-01-03  0.0  0.249155  0.549637   0.249001   1.709467
# 2000-01-04  0.0 -0.053239 -0.852358   0.127729   2.020533
# 2000-01-05  0.0 -0.112559 -0.155455   0.503647   2.308505

# %%
import numpy as np
import pandas as pd
index = pd.date_range('1/1/2000',periods=8) 
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
df['D']=df['A']/df['B']
df['E'] = np.sum(df, axis=1)
df = df.sub(df['A'], axis=0) # A열의 데이터를 기준으로 열 우선 계산. 전체 데이터를 A열 값으로 빼기(sub)
df = df.div(df['D'], axis=0)
df.head()
# Out:
#               A           B          C    D           E
# 2000-01-01  0.0    0.106787  -1.655703  1.0    5.399706
# 2000-01-02  0.0   92.306662  63.954393  1.0  252.598186
# 2000-01-03  0.0   -0.084352   0.006625  1.0    1.203342
# 2000-01-04  0.0   34.568194  20.867894  1.0  126.742296
# 2000-01-05  0.0  112.243982  42.834723  1.0  214.940969

# %%
df.to_csv('test.csv')

# %%
import pandas as pd
df = pd.read_csv('age.csv', encoding='cp949', index_col = 0)
df.head()
# Out:
#                                 총인구수  연령구간인구수     0세     1세     2세     3세  \
# 행정구역
# 서울특별시  (1100000000)          9857426  9857426  61253  70532  74322  72482
# 서울특별시 종로구 (1111000000)        154770   154770    652    794    911    895
# 서울특별시 종로구 청운효자동(1111051500)    13272    13272     81     82     90    105
# 서울특별시 종로구 사직동(1111053000)       9441     9441     43     63     75     68
# 서울특별시 종로구 삼청동(1111054000)       2907     2907     12      4     22     13
#
#                                 4세     5세     6세     7세  ...   91세   92세  \
# 행정구역                                                     ...
# 서울특별시  (1100000000)          71688  78941  75386  75929  ...  5892  4695
# 서울특별시 종로구 (1111000000)         859   1046    909   1012  ...   149   115
# 서울특별시 종로구 청운효자동(1111051500)     97    116    117    116  ...    12    14
# 서울특별시 종로구 사직동(1111053000)       76     81     74     83  ...    11    13
# 서울특별시 종로구 삼청동(1111054000)       12     13     20     11  ...     5     2
#
# ...

# %%
import pandas as pd
df = pd.read_csv('age.csv', encoding='cp949', index_col = 0)
df = df.div(df['총인구수'], axis=0)
del df['총인구수'], df['연령구간인구수']
df.head()
# Out:
#                                    0세        1세        2세        3세        4세  \
# 행정구역
# 서울특별시  (1100000000)          0.006214  0.007155  0.007540  0.007353  0.007272
# 서울특별시 종로구 (1111000000)       0.004213  0.005130  0.005886  0.005783  0.005550
# 서울특별시 종로구 청운효자동(1111051500)  0.006103  0.006178  0.006781  0.007911  0.007309
# 서울특별시 종로구 사직동(1111053000)    0.004555  0.006673  0.007944  0.007203  0.008050
# 서울특별시 종로구 삼청동(1111054000)    0.004128  0.001376  0.007568  0.004472  0.004128
#
#                                    5세        6세        7세        8세        9세  \
# 행정구역
# 서울특별시  (1100000000)          0.008008  0.007648  0.007703  0.007281  0.007726
# 서울특별시 종로구 (1111000000)       0.006758  0.005873  0.006539  0.005938  0.006500
# 서울특별시 종로구 청운효자동(1111051500)  0.008740  0.008816  0.008740  0.007685  0.008966
# 서울특별시 종로구 사직동(1111053000)    0.008580  0.007838  0.008791  0.006991  0.009215
# 서울특별시 종로구 삼청동(1111054000)    0.004472  0.006880  0.003784  0.007224  0.007224
#
# ...

# %%
import pandas as pd
df = pd.read_csv('age.csv', encoding='cp949', index_col = 0)
df = df.div(df['총인구수'], axis=0)
del df['총인구수'], df['연령구간인구수']

name = input('원하는 지역의 이름을 입력해주세요 : ')
a = df.index.str.contains(name) # 인덱스 문자열에 name을 포함하는 해당 행을 찾아서 해당 지역의 인구 구조 저장
df2 = df[a]
df2
# Out:
# 원하는 지역의 이름을 입력해주세요 : 수지구
#                                      0세        1세        2세        3세  \
# 행정구역
# 경기도 용인시 수지구 (4146500000)       0.006771  0.008771  0.010017  0.010566
# 경기도 용인시 수지구 풍덕천1동(4146551000)  0.009145  0.010421  0.010339  0.010068
# 경기도 용인시 수지구 풍덕천2동(4146552000)  0.007717  0.009792  0.011866  0.011960
# 경기도 용인시 수지구 신봉동(4146553000)    0.005429  0.007432  0.008671  0.009646
# 경기도 용인시 수지구 죽전1동(4146554000)   0.006665  0.008932  0.010809  0.010742
# 경기도 용인시 수지구 죽전2동(4146555000)   0.010490  0.011988  0.011730  0.011368
# 경기도 용인시 수지구 동천동(4146556000)    0.006267  0.008374  0.010317  0.011220
# 경기도 용인시 수지구 상현1동(4146557000)   0.006255  0.008236  0.009196  0.010426
# 경기도 용인시 수지구 상현2동(4146558000)   0.006338  0.008618  0.008618  0.010425
# 경기도 용인시 수지구 성복동(4146559000)    0.004576  0.006696  0.008868  0.009411
#
#                                      4세        5세        6세        7세  \
# 행정구역
# 경기도 용인시 수지구 (4146500000)       0.010683  0.011985  0.011937  0.012235
# ...

# %%
import pandas as pd
df = pd.read_csv('age.csv', encoding='cp949', index_col = 0)
df = df.div(df['총인구수'], axis=0)
del df['총인구수'], df['연령구간인구수']

name = input('원하는 지역의 이름을 입력해주세요 : ')
a = df.index.str.contains(name) # name을 포함하는 해당 행을 찾아서 해당 지역의 인구 구조 저장
df2 = df[a]

import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
plt.style.use('ggplot')
df2.T.plot()
plt.show()
# Out:
# 원하는 지역의 이름을 입력해주세요 : 신림동

# %%
import pandas as pd
df = pd.read_csv('age.csv', encoding='cp949', index_col = 0)
df = df.div(df['총인구수'], axis=0)
del df['총인구수'], df['연령구간인구수']

name = input('원하는 지역의 이름을 입력해주세요 : ')
a = df.index.str.contains(name) # name을 포함하는 해당 행을 찾아서 해당 지역의 인구 구조 저장
df2 = df[a]

import numpy as np
x = df.sub(df2.iloc[0],axis=1) # 궁금한 지역 A의 인구 비율에서 B의 인구 비율을 뺀다
y = np.abs(x) # 차이들에 절댓값 씌우고
z = y.sum(axis=1) # 모두 더하기
i = z.sort_values().index[:5] # 그 차이가 가장 작은 지역 상위 5곳을 보여줘라.

import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
plt.style.use('ggplot')
df.loc[i].T.plot() # 결과 꺾은선 그래프로 보여줘라
plt.show()
# Out:
# 원하는 지역의 이름을 입력해주세요 : 신림동

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
df = pd.read_csv('age.csv', encoding='cp949', index_col = 0)
df = df.div(df['총인구수'], axis=0)
del df['총인구수'], df['연령구간인구수']

name = input('원하는 지역의 이름을 입력해주세요 : ')
a = df.index.str.contains(name) 
df2 = df[a]

# 윗 버전에서 코드 한줄로 합친거
df.loc[np.power(df.sub(df2.iloc[0], axis=1), 2).sum(axis=1).sort_values().index[:5]].T.plot()

plt.show()
# Out:
# 원하는 지역의 이름을 입력해주세요 : 신도림
